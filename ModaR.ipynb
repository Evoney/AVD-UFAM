# %% [markdown]
# Implementando a função que retorna a moda de um conjunto de valores

# %%
# função da moda

moda = function(x) {
z = table(as.vector(x)) 
names(z)[z == max(z)]
}

# %%
# Evento teste da aula 

n = c(3, 4, 4, 5, 5, 6, 7, 8, 9, 9, 9, 10, 11, 12, 12, 13)
moda(n)
# Out:
# [1] "9"
