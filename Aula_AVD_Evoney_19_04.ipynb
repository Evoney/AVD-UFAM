# %%
# Teste de hipótese

x <- c(6.2, 6.6, 7.1, 7.4, 7.6, 7.9, 8.0, 8.3, 8.4, 8.5, 8.6, 8.8,
8.8, 9.1, 9.2, 9.4, 9.4, 9.7, 9.9, 10.2, 10.4, 10.8, 11.3, 11.9)

# %%
# teste de normalidade para alpha = 0.05
shapiro.test(x)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  x
# W = 0.99245, p-value = 0.9994

# %%
# t teste
t.test(x, mu=9, alternative="two.sided", conf.level=0.95)
# Out:
# 	One Sample t-test
#
# data:  x
# t = -0.35687, df = 23, p-value = 0.7244
# alternative hypothesis: true mean is not equal to 9
# 95 percent confidence interval:
#  8.292017 9.499649
# sample estimates:
# mean of x
#  8.895833

# %%
depois = c(38.9, 61.2, 73.3, 21.8, 63.4, 64.6, 48.4, 48.8, 48.5)
antes = c(67.8, 60, 63.4, 76, 89.4, 73.3, 67.3, 61.3, 62.4)

# %%
# Computar o t-test
res <- t.test(depois, antes, var.equal = TRUE)
res
# Out:
# 	Two Sample t-test
#
# data:  depois and antes
# t = -2.7842, df = 16, p-value = 0.01327
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -29.748019  -4.029759
# sample estimates:
# mean of x mean of y
#  52.10000  68.98889
